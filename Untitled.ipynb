# %%
from numpy import *
import math

# %%
arr = array([633.1,632.3,633.2,632.9,633.1,634.7,633.6,632.4,633.0,634.7])
average(arr)
# Out:
# 633.3

# %%
var(arr,ddof=1)
# Out:
# 0.6844444444444879

# %%
(633.3 - 633) / math.sqrt(0.68/10)
# Out:
# 1.150447483270881

# %%
(25.29-25.5) / math.sqrt(2.23/20)
# Out:
# -0.6289003856472564

# %%
4/math.sqrt(9/10)
# Out:
# 4.216370213557839

# %%
(9*13.7+7*15.2)/16
# Out:
# 14.35625

# %%
6/(14.35625*(1/8+1/10))
# Out:
# 1.8574952837033814

# %%
((44-39)**2/44) + ((174-188)**2/174)+((87-68)**2/87)
# Out:
# 5.844043887147335

# %%
print(1/3.95)
print(4.3/1.03)
# Out:
# 0.2531645569620253
# 4.174757281553398

# %%
a = array([3.19,3.06,2.51])
b = array([3.46,3.62,3.71])
c = array([3.90,3.90,3.67])

average(concatenate([a,b,c]))
print(average(a))
print(average(b))
print(average(c))
# Out:
# 2.92
# 3.5966666666666662
# 3.823333333333333

# %%
3 * ((3.4 - 2.92) ** 2) + 3*((3.4-3.59)**2) + 3*((3.4 - 3.82) ** 2)
# Out:
# 1.3287

# %%
10350-3750-1750-1250
3750/25
# Out:
# 150.0

# %%
3600,25,350,150,7,3
# Out:
# (3600, 25, 350, 150, 7, 3)

# %%
import pandas as pd
import matplotlib as mp

# %%
data = list(map(int,input().split()))
# Out:
#  800.000000	-0.067582 799.000000	-0.067362 798.000000	-0.067144 797.000000	-0.066925 796.000000	-0.066715 795.000000	-0.066514 794.000000	-0.066325 793.000000	-0.066138 792.000000	-0.065959 791.000000	-0.065779 790.000000	-0.065604 789.000000	-0.065443 788.000000	-0.065287 787.000000	-0.065137 786.000000	-0.064996 785.000000	-0.064864 784.000000	-0.064741 783.000000	-0.064630 782.000000	-0.064520 781.000000	-0.064419 780.000000	-0.064327 779.000000	-0.064237 778.000000	-0.064157 777.000000	-0.064080 776.000000	-0.064009 775.000000	-0.063945 774.000000	-0.063891 773.000000	-0.063847 772.000000	-0.063800 771.000000	-0.063748 770.000000	-0.063700 769.000000	-0.063657 768.000000	-0.063614 767.000000	-0.063589 766.000000	-0.063549 765.000000	-0.063521 764.000000	-0.063486 763.000000	-0.063452 762.000000	-0.063417 761.000000	-0.063379 760.000000	-0.063343 759.000000	-0.063305 758.000000	-0.063268 757.000000	-0.063226 756.000000	-0.063177 755.000000	-0.063109 754.000000	-0.063039 753.000000
# ...

# %%
int(800.000000)
# Out:
# 800

# %%
data = map(int,input().split())
# Out:
#  800.000000	-0.067582 799.000000	-0.067362 798.000000	-0.067144 797.000000	-0.066925 796.000000	-0.066715 795.000000	-0.066514 794.000000	-0.066325 793.000000	-0.066138 792.000000	-0.065959 791.000000	-0.065779 790.000000	-0.065604 789.000000	-0.065443 788.000000	-0.065287 787.000000	-0.065137 786.000000	-0.064996 785.000000	-0.064864 784.000000	-0.064741 783.000000	-0.064630 782.000000	-0.064520 781.000000	-0.064419 780.000000	-0.064327 779.000000	-0.064237 778.000000	-0.064157 777.000000	-0.064080 776.000000	-0.064009 775.000000	-0.063945 774.000000	-0.063891 773.000000	-0.063847 772.000000	-0.063800 771.000000	-0.063748 770.000000	-0.063700 769.000000	-0.063657 768.000000	-0.063614 767.000000	-0.063589 766.000000	-0.063549 765.000000	-0.063521 764.000000	-0.063486 763.000000	-0.063452 762.000000	-0.063417 761.000000	-0.063379 760.000000	-0.063343 759.000000	-0.063305 758.000000	-0.063268 757.000000	-0.063226 756.000000	-0.063177 755.000000	-0.063109 754.000000	-0.063039 753.000000
# ...

# %%
data

# %%
list(data)[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-c45ac2e61aed> in <module>
# ----> 1 list(data)[0]
#
# ValueError: invalid literal for int() with base 10: '800.000000'

# %%
data = list(map(float,input().split()))
# Out:
#  800.000000	-0.067582 799.000000	-0.067362 798.000000	-0.067144 797.000000	-0.066925 796.000000	-0.066715 795.000000	-0.066514 794.000000	-0.066325 793.000000	-0.066138 792.000000	-0.065959 791.000000	-0.065779 790.000000	-0.065604 789.000000	-0.065443 788.000000	-0.065287 787.000000	-0.065137 786.000000	-0.064996 785.000000	-0.064864 784.000000	-0.064741 783.000000	-0.064630 782.000000	-0.064520 781.000000	-0.064419 780.000000	-0.064327 779.000000	-0.064237 778.000000	-0.064157 777.000000	-0.064080 776.000000	-0.064009 775.000000	-0.063945 774.000000	-0.063891 773.000000	-0.063847 772.000000	-0.063800 771.000000	-0.063748 770.000000	-0.063700 769.000000	-0.063657 768.000000	-0.063614 767.000000	-0.063589 766.000000	-0.063549 765.000000	-0.063521 764.000000	-0.063486 763.000000	-0.063452 762.000000	-0.063417 761.000000	-0.063379 760.000000	-0.063343 759.000000	-0.063305 758.000000	-0.063268 757.000000	-0.063226 756.000000	-0.063177 755.000000	-0.063109 754.000000	-0.063039 753.000000
# ...

# %%
data = array(data)

# %%
m_w_30min = array_split(data,len(data)//2)

# %%
m_w_30min[0]
# Out:
# array([ 8.0000e+02, -6.7582e-02])

# %%
df = pd.DataFrame(m_w_30min)
df[0]
# Out:
# 0      800.0
# 1      799.0
# 2      798.0
# 3      797.0
# 4      796.0
#        ...
# 496    304.0
# 497    303.0
# 498    302.0
# 499    301.0
# 500    300.0
# Name: 0, Length: 501, dtype: float64

# %%
ws_200 = array(list(map(float,input().split())))
ws_215 = array(list(map(float,input().split())))
ws_230 = array(list(map(float,input().split())))

ws_200_arr = array_split(ws_200,len(ws_200//2))
ws_215_arr = array_split(ws_215,len(ws_215//2))
ws_230_arr = array_split(ws_230,len(ws_230//2))
# Out:
#  800.000000	-0.041579 799.000000	-0.041293 798.000000	-0.041018 797.000000	-0.040742 796.000000	-0.040485 795.000000	-0.040240 794.000000	-0.040006 793.000000	-0.039793 792.000000	-0.039590 791.000000	-0.039410 790.000000	-0.039235 789.000000	-0.039077 788.000000	-0.038934 787.000000	-0.038812 786.000000	-0.038704 785.000000	-0.038607 784.000000	-0.038530 783.000000	-0.038467 782.000000	-0.038415 781.000000	-0.038372 780.000000	-0.038343 779.000000	-0.038319 778.000000	-0.038312 777.000000	-0.038302 776.000000	-0.038307 775.000000	-0.038320 774.000000	-0.038342 773.000000	-0.038361 772.000000	-0.038378 771.000000	-0.038388 770.000000	-0.038403 769.000000	-0.038418 768.000000	-0.038429 767.000000	-0.038450 766.000000	-0.038463 765.000000	-0.038475 764.000000	-0.038478 763.000000	-0.038480 762.000000	-0.038480 761.000000	-0.038476 760.000000	-0.038470 759.000000	-0.038451 758.000000	-0.038424 757.000000	-0.038391 756.000000	-0.038356 755.000000	-0.038318 754.000000	-0.038269 753.000000
# ...

# %%
ws_200_df = pd.DataFrame(ws_200_arr)
ws_215_df = pd.DataFrame(ws_215_arr)
ws_230_df = pd.DataFrame(ws_230_arr)

# %%
ws_200_df
# Out:
#                0
# 0     800.000000
# 1      -0.041579
# 2     799.000000
# 3      -0.041293
# 4     798.000000
# ...          ...
# 997    10.000000
# 998   301.000000
# 999    10.000000
# 1000  300.000000
# 1001   10.000000
#
# [1002 rows x 1 columns]

# %%
fig,ax = plt.subplots(1,3)
for axi,df in zip(ax,[ws_200_df,ws_215_df,ws_230_df]):
    axi.scatter(df[0],df[1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: 1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-98-41c947ecee16> in <module>
#       1 fig,ax = plt.subplots(1,3)
#       2 for axi,df in zip(ax,[ws_200_df,ws_215_df,ws_230_df]):
# ----> 3     axi.scatter(df[0],df[1])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3453             if self.columns.nlevels > 1:
# ...

# %%
df.plot.scatter(x='波長（nm）',y='吸光度')
# Out:
# <AxesSubplot:xlabel='波長（nm）', ylabel='吸光度'>
